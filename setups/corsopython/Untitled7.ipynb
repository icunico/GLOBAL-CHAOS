# %%
import os
import glob

# %%
glob.glob('txt')
# Out:
# []

# %%
import sys

# %%
import numpy as np
a= np.array([1.,2,3])

# %%
c=np.array(['lof', 3, 2]) 
c
# Out:
# array(['lof', '3', '2'], dtype='<U21')

# %%
type(a)
# Out:
# numpy.ndarray

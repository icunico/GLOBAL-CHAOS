# %%
import math

# %%
math.cos(math.pi/4)
# Out:
# 0.7071067811865476

# %%
math.log(1024,2)
# Out:
# 10.0

# %%
math.e
# Out:
# 2.718281828459045

# %% [raw]
# pip install random

# %%
import random

# %% [raw]
# random.choice(['apple', 'pear', 'banana'])

# %% [raw]
# random.sample
